# %%
# started 9-24-2025

# %%
import pandas as pd
import xarray as xr
import glob
import time
from tqdm import tqdm
from pathlib import Path

# %%
fires = pd.read_csv("../attempt 2/pt2_full_fires_socal.csv")

# %%
fires.head()
# Out:
#    OBJECTID  FIRE_YEAR  DISCOVERY_DATE  FIRE_SIZE STAT_CAUSE_DESCR   LATITUDE  \
# 0       110       2005       2453540.5       10.0    Equipment Use  33.718889
# 1       155       2005       2453411.5        3.0   Debris Burning  34.748333
# 2       178       2005       2453544.5        4.2    Equipment Use  34.466667
# 3      1053       2005       2453559.5        3.0    Miscellaneous  34.479444
# 4      1282       2005       2453582.5        2.0        Lightning  33.110833
#
#     LONGITUDE  OBJECTID.1  temp_max_F  humidity_pct  precip_in  windspeed_mph
# 0 -117.433611         110       73.04            89   0.062992       6.028589
# 1 -119.410278         155       58.46            79   0.000000       4.536979
# 2 -119.828333         178       77.54            76   0.000000      15.972654
# 3 -118.768611        1053       82.76            86   0.000000       6.028589
# 4 -116.847222        1282       87.62            88   0.000000       8.763207

# %%
fires.shape
# Out:
# (2926, 12)

# %%
fires['time'] = pd.to_datetime(fires['DISCOVERY_DATE'])

# %%
ndvi_files = sorted(glob.glob("../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502/*.nc4"))

# %%
ndvi_files
# Out:
# ['../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2000_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2000_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2001_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2001_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2002_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2002_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2003_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2003_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2004_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2004_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2005_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2005_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2006_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2006_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2007_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2007_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2008_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2008_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2009_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2009_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2010_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2010_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2011_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2011_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2012_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2012_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2013_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2013_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2014_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2014_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_2_2015_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_2_2015_0712.nc4']

# %%
def parse_ndvi_file_dates(ndvi_files):
    file_dates = []
    for f in ndvi_files:
        name = Path(f).name  # get filename safely
        parts = name.split("_")
        year = int(parts[-2])
        
        # Remove file extension before extracting day
        day_str = parts[-1].split(".")[0]  # '0106.nc4' -> '0106'
        month = int(day_str[:2])
        day = int(day_str[2:])
        
        start_date = pd.Timestamp(year=year, month=month, day=day)
        file_dates.append((start_date, f))
    
    # Sort by date just in case
    file_dates.sort(key=lambda x: x[0])
    return file_dates

# %%
def pick_file_for_date(fire_date, ndvi_file_dates):
    """
    fire_date: pd.Timestamp
    ndvi_file_dates: output of parse_ndvi_file_dates(ndvi_files)
    """
    fire_date = pd.Timestamp(fire_date)
    
    # iterate through files in order, pick the last file whose start_date <= fire_date
    chosen_file = ndvi_file_dates[0][1]  # default first file
    for start_date, f in ndvi_file_dates:
        if fire_date >= start_date:
            chosen_file = f
        else:
            break
    return chosen_file

# %%
def get_ndvi_for_point(lat, lon, date, file):
    ds = xr.open_dataset(file)
    
    # find nearest time
    time_index = ds['time'].sel(time=date, method="nearest")
    
    # get nearest lat/lon grid point
    ndvi_value = ds['ndvi'].sel(lat=lat, lon=lon, time=time_index, method="nearest").values.item()
    
    ds.close()  # free memory
    return ndvi_value

# %%
ndvi_file_dates = parse_ndvi_file_dates(ndvi_files)

# %%
ndvi_values = []

for _, row in tqdm(fires.iterrows(), total=len(fires)):
    # pick the NDVI file for this fire event
    ndvi_file = pick_file_for_date(row['time'], ndvi_file_dates)
    
    # get NDVI value
    ndvi = get_ndvi_for_point(
        row['LATITUDE'], row['LONGITUDE'], row['time'], ndvi_file
    )
    ndvi_values.append(ndvi)
# Out:
# 100%|██████████| 2926/2926 [00:27<00:00, 108.32it/s]

# %%
# Add NDVI values to the dataframe
fires['ndvi'] = ndvi_values

# %%
fires
# Out:
#       OBJECTID  FIRE_YEAR  DISCOVERY_DATE  FIRE_SIZE   STAT_CAUSE_DESCR  \
# 0          110       2005       2453540.5       10.0      Equipment Use
# 1          155       2005       2453411.5        3.0     Debris Burning
# 2          178       2005       2453544.5        4.2      Equipment Use
# 3         1053       2005       2453559.5        3.0      Miscellaneous
# 4         1282       2005       2453582.5        2.0          Lightning
# ...        ...        ...             ...        ...                ...
# 2921   1880367       2009       2455012.5        2.0      Equipment Use
# 2922   1880400       2009       2454954.5       73.0  Missing/Undefined
# 2923   1880420       2010       2455345.5       50.0  Missing/Undefined
# 2924   1880428       2013       2456402.5        4.5           Children
# 2925   1880442       2015       2457363.5       11.0      Miscellaneous
#
#        LATITUDE   LONGITUDE  OBJECTID.1  temp_max_F  humidity_pct  precip_in  \
# 0     33.718889 -117.433611         110       73.04            89   0.062992
# 1     34.748333 -119.410278         155       58.46            79   0.000000
# 2     34.466667 -119.828333         178       77.54            76   0.000000
# 3     34.479444 -118.768611        1053       82.76            86   0.000000
# 4     33.110833 -116.847222        1282       87.62            88   0.000000
# ...         ...         ...         ...         ...           ...        ...
# 2921  33.297738 -117.003073     1880367       85.64            78   0.000000
# 2922  33.892120 -117.079065     1880400       65.84            91   0.000000
# 2923  32.906591 -116.942448     1880420       66.56            90   0.015748
# 2924  34.633333 -118.966666     1880428       65.84            44   0.000000
# 2925  34.450000 -118.583333     1880442       74.12            39   0.000000
#
#       windspeed_mph                          time    ndvi
# 0          6.028589 1970-01-01 00:00:00.002453540  5016.0
# 1          4.536979 1970-01-01 00:00:00.002453411  3357.0
# 2         15.972654 1970-01-01 00:00:00.002453544  4356.0
# 3          6.028589 1970-01-01 00:00:00.002453559  3124.0
# 4          8.763207 1970-01-01 00:00:00.002453582  4180.0
# ...             ...                           ...     ...
# 2921       7.271597 1970-01-01 00:00:00.002455012  5071.0
# 2922       6.774394 1970-01-01 00:00:00.002454954  2988.0
# 2923      11.249223 1970-01-01 00:00:00.002455345  3081.0
# 2924       7.147296 1970-01-01 00:00:00.002456402  4854.0
# 2925       7.085146 1970-01-01 00:00:00.002457363  2154.0
#
# [2926 rows x 14 columns]

# %%
old_fires = pd.read_csv("../attempt 2/pt2_full_fires_socal.csv")

# %%
old_fires
# Out:
#       OBJECTID  FIRE_YEAR  DISCOVERY_DATE  FIRE_SIZE   STAT_CAUSE_DESCR  \
# 0          110       2005       2453540.5       10.0      Equipment Use
# 1          155       2005       2453411.5        3.0     Debris Burning
# 2          178       2005       2453544.5        4.2      Equipment Use
# 3         1053       2005       2453559.5        3.0      Miscellaneous
# 4         1282       2005       2453582.5        2.0          Lightning
# ...        ...        ...             ...        ...                ...
# 2921   1880367       2009       2455012.5        2.0      Equipment Use
# 2922   1880400       2009       2454954.5       73.0  Missing/Undefined
# 2923   1880420       2010       2455345.5       50.0  Missing/Undefined
# 2924   1880428       2013       2456402.5        4.5           Children
# 2925   1880442       2015       2457363.5       11.0      Miscellaneous
#
#        LATITUDE   LONGITUDE  OBJECTID.1  temp_max_F  humidity_pct  precip_in  \
# 0     33.718889 -117.433611         110       73.04            89   0.062992
# 1     34.748333 -119.410278         155       58.46            79   0.000000
# 2     34.466667 -119.828333         178       77.54            76   0.000000
# 3     34.479444 -118.768611        1053       82.76            86   0.000000
# 4     33.110833 -116.847222        1282       87.62            88   0.000000
# ...         ...         ...         ...         ...           ...        ...
# 2921  33.297738 -117.003073     1880367       85.64            78   0.000000
# 2922  33.892120 -117.079065     1880400       65.84            91   0.000000
# 2923  32.906591 -116.942448     1880420       66.56            90   0.015748
# 2924  34.633333 -118.966666     1880428       65.84            44   0.000000
# 2925  34.450000 -118.583333     1880442       74.12            39   0.000000
#
#       windspeed_mph
# 0          6.028589
# 1          4.536979
# 2         15.972654
# 3          6.028589
# 4          8.763207
# ...             ...
# 2921       7.271597
# 2922       6.774394
# 2923      11.249223
# 2924       7.147296
# 2925       7.085146
#
# [2926 rows x 12 columns]

# %%
ndvi_files = sorted(glob.glob("../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502/*.nc4"))

# %%
ndvi_files
# Out:
# ['../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2000_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2000_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2001_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2001_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2002_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2002_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2003_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2003_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2004_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2004_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2005_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2005_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2006_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2006_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2007_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2007_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2008_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2008_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2009_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2009_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2010_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2010_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2011_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2011_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2012_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2012_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2013_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2013_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2014_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_1_2014_0712.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_2_2015_0106.nc4',
#  '../ndvi data/Global_Veg_Greenness_GIMMS_3G_2187_1-20250924_160502\\ndvi3g_geo_v1_2_2015_0712.nc4']

# %%
def get_ndvi_for_point(lat, lon, date, file):
    ds = xr.open_dataset(file)
    
    # find nearest time
    time_index = ds['time'].sel(time=date, method="nearest")
    
    # get nearest lat/lon grid point
    ndvi_value = ds['ndvi'].sel(lat=lat, lon=lon, time=time_index, method="nearest").values.item()
    
    ds.close()  # free memory
    return ndvi_value

# %%
ndvi_values = []
for _, row in tqdm(old_fires.iterrows(), total=len(old_fires)):
    # choose the right file based on row['time']
    ndvi_file = pick_file_for_date(row['time'], ndvi_files)
    
    ndvi = get_ndvi_for_point(
        row['latitude'], row['longitude'], row['time'], ndvi_file
    )
    ndvi_values.append(ndvi)

old_fires['ndvi'] = ndvi_values
# Out:
#   0%|          | 0/2926 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 ndvi_values = []
#       2 for _, row in tqdm(old_fires.iterrows(), total=len(old_fires)):
#       3     # choose the right file based on row['time']
# ----> 4     ndvi_file = pick_file_for_date(row['time'], ndvi_files)
#       6     ndvi = get_ndvi_for_point(
#       7         row['latitude'], row['longitude'], row['time'], ndvi_file
#       8     )
#       9     ndvi_values.append(ndvi)
#
# NameError: name 'pick_file_for_date' is not defined
