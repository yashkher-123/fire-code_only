# %%
# started 10-18-2025

# %%
import pandas as pd

# %%
fires_slope = pd.read_csv("../topo/fires_with_slope.csv")
fires_slope = fires_slope[["FIRE_SIZE","temp_max_F","humidity_pct","precip_in","windspeed_mph","ndvi","pop_density","slope"]]

# %%
fires_smogn = pd.read_csv("../synthetic_fires/fires_smogn.csv")
fires_smogn = fires_smogn[["FIRE_SIZE","temp_max_F","humidity_pct","precip_in","windspeed_mph","ndvi","pop_density","slope"]]

# %%
fires_slope.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2926 entries, 0 to 2925
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIRE_SIZE      2926 non-null   float64
#  1   temp_max_F     2926 non-null   float64
#  2   humidity_pct   2926 non-null   int64
#  3   precip_in      2926 non-null   float64
#  4   windspeed_mph  2926 non-null   float64
#  5   ndvi           2925 non-null   float64
#  6   pop_density    2926 non-null   float64
#  7   slope          2926 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 183.0 KB

# %%
fires_smogn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268 entries, 0 to 2267
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIRE_SIZE      2268 non-null   float64
#  1   temp_max_F     2268 non-null   float64
#  2   humidity_pct   2268 non-null   float64
#  3   precip_in      2268 non-null   float64
#  4   windspeed_mph  2268 non-null   float64
#  5   ndvi           2268 non-null   float64
#  6   pop_density    2268 non-null   float64
#  7   slope          2268 non-null   float64
# dtypes: float64(8)
# memory usage: 141.9 KB

# %%
common_rows = pd.merge(fires_slope, fires_smogn, how="inner")
num_common = len(common_rows)

# %%
num_common
# Out:
# 1463
